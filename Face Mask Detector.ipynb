# %% [markdown]
# <h2> Importing the reqiured packages</h2>

# %%
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Activation, Conv2D, MaxPool2D, Flatten, Dropout, BatchNormalization
from sklearn.metrics import classification_report,confusion_matrix
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import AveragePooling2D
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelBinarizer
import numpy as np
from sklearn.model_selection import train_test_split
import os 
import pathlib 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import matplotlib.image as mpimg
import random
import cv2

# %%
from keras.models import Sequential
from tensorflow.keras import layers
from keras.layers import Conv2D, MaxPooling2D,Flatten

# %%
DIRECT = r"D:\Face Mask\train"

# %%
CATE_G = ["with_mask", "without_mask"]

# %%
photos = []
captions = []

# %% [markdown]
# <h2> DATA PREPROCESSING </h2>

# %%
import os
for category in CATE_G:
    path = os.path.join(DIRECT, category)
    for img in os.listdir(path):
        img_path = os.path.join(path, img)
        image = load_img(img_path, target_size=(224, 224))
        image = img_to_array(image)
        image = preprocess_input(image)
        photos.append(image)
        captions.append(category)

# %% [markdown]
# <H3> One hot encoding</H3>

# %%
lb = LabelBinarizer()
captions = lb.fit_transform(captions)
captions = to_categorical(captions)

# %%
photos = np.array(data, dtype="float32")

# %%
captions = np.array(captions)

# %%
x_train,x_test,y_train,y_test= train_test_split(photos, captions,test_size=0.20, stratify=labels, random_state=42)

# %% [markdown]
# <H4> Model builting using MobileNetCV </H4>

# %%
base_model = tf.keras.applications.MobileNet(input_shape=[224,224,3], weights = "imagenet", include_top=False)
base_model.trainable = False

model = Sequential()
model.add(base_model)
model.add(AveragAePooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(512, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(50, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(2, activation='sigmoid'))
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %% [markdown]
# <h3>Model fitting</h3>

# %%
model.fit(x_train,y_train, epochs=20,validation_split= 0.2, batch_size=32)
# Out:
# Epoch 1/20
# 31/31 [==============================] - 78s 2s/step - loss: 0.3125 - accuracy: 0.9461 - val_loss: 0.0315 - val_accuracy: 0.9876
# Epoch 2/20
# 31/31 [==============================] - 62s 2s/step - loss: 0.1202 - accuracy: 0.9844 - val_loss: 3.4830e-05 - val_accuracy: 1.0000
# Epoch 3/20
# 31/31 [==============================] - 63s 2s/step - loss: 0.0391 - accuracy: 0.9938 - val_loss: 0.0392 - val_accuracy: 0.9917
# Epoch 4/20
# 31/31 [==============================] - 65s 2s/step - loss: 0.0414 - accuracy: 0.9927 - val_loss: 7.6022e-04 - val_accuracy: 1.0000
# Epoch 5/20
# 31/31 [==============================] - 64s 2s/step - loss: 0.0391 - accuracy: 0.9938 - val_loss: 3.4485e-04 - val_accuracy: 1.0000
# Epoch 6/20
# 31/31 [==============================] - 98s 3s/step - loss: 0.0473 - accuracy: 0.9938 - val_loss: 0.0833 - val_accuracy: 0.9876
# Epoch 7/20
# ...

# %%
model.evaluate(x_test,y_test)
# Out:
# 10/10 [==============================] - 15s 1s/step - loss: 0.0991 - accuracy: 0.9934
# [0.09908086061477661, 0.9933775067329407]

# %%
predictions = model.predict(x_test)

predict=[]

for i in range(len(predictions)):
    if predictions[i][0]>0.5:
        predict.append(1)
    else:
        predict.append(0)
# Out:
# 10/10 [==============================] - 19s 1s/step

# %% [markdown]
# <h3> FITTING THE ENTIRE DATA </h3>

# %%
model.fit(photos, captions, epochs=20,validation_split= 0.2, batch_size=32)
# Out:
# Epoch 1/20
# 38/38 [==============================] - 95s 2s/step - loss: 0.3469 - accuracy: 0.9353 - val_loss: 0.0265 - val_accuracy: 0.9901
# Epoch 2/20
# 38/38 [==============================] - 71s 2s/step - loss: 0.0456 - accuracy: 0.9950 - val_loss: 2.3479e-10 - val_accuracy: 1.0000
# Epoch 3/20
# 38/38 [==============================] - 76s 2s/step - loss: 0.0604 - accuracy: 0.9900 - val_loss: 3.4653e-05 - val_accuracy: 1.0000
# Epoch 4/20
# 38/38 [==============================] - 72s 2s/step - loss: 0.0367 - accuracy: 0.9967 - val_loss: 3.9710e-08 - val_accuracy: 1.0000
# Epoch 5/20
# 38/38 [==============================] - 76s 2s/step - loss: 0.0761 - accuracy: 0.9942 - val_loss: 0.0278 - val_accuracy: 0.9901
# Epoch 6/20
# 38/38 [==============================] - 85s 2s/step - loss: 0.0160 - accuracy: 0.9975 - val_loss: 1.8445e-04 - val_accuracy: 1.0000
# Epoch 7/20
# ...

# %%
model_name = "D:/Face_mask_model.h5"
tf.keras.models.save_model(model, model_name)

# %%
os.getcwd()
print(os.listdir())
# Out:
# ['.git', '.gitattributes', '.ipynb_checkpoints', 'Adults.ipynb', 'Air passengers-Forecasting.ipynb', 'Another.csv', 'Automobile.ipynb', 'BigMart-GradientRegressor.ipynb', 'bigmart.csv', 'BigMartHackathon.csv', 'Black Friday- Hackathon.ipynb', 'Black Friday-pca.ipynb', 'BLK.csv', 'BMAnother.csv', 'CGPA calculator.ipynb', 'cgpa_cal.ipynb', 'clas(LogReg)- credict_card.ipynb', 'CNN.ipynb', 'college.xlsx', 'college1.csv', 'data.npy', 'Decision_Tree_Model.pkl', 'DeepLearn(Seq)-Brstcancer.ipynb', 'drowsiness-detection-model-tensorflow.ipynb', 'DTC-card.ipynb', 'EXAM1.ipynb', 'Excel pandas.ipynb', 'Excel_pandas.ipynb', 'Face Mask Detector.ipynb', 'face Mask.ipynb', 'Facemask_model.h5', 'Face_mask_model.h5', 'Flight_Distance.ipynb', 'Games_model1.ipynb', 'Games_model2.ipynb', 'Golf- LabelEn&NaiveBayes.ipynb', 'haarcascade_frontalface_alt.xml', 'haarcascade_frontalface_default.xml', 'Hackathon.csv', 'Hackathon_result.csv', 'hackothan.ipynb', 'Height and Weight(SLR).ipynb', 'Hello.txt', 'Image 
# ...

# %% [markdown]
# <h2> code for face detection </h2>

# %%
import cv2
import os
import tensorflow as tf
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.models import load_model
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
import numpy as np

# %config Completer.use_jedi = False

# %%
from pygame import mixer
import time
# Out:
# pygame 2.1.2 (SDL 2.0.18, Python 3.9.12)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %% [markdown]
# <h3> Alarm generation </h3>

# %%
mixer.init()
sound = mixer.Sound('mixkit-scanning-sci-fi-alarm-905.wav')
face_classifier = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")
mask_detection = tf.keras.models.load_model("mask_bestmodel.h5")

# %%
text_mask = "WITH MASK"
text_no_mask = "WITHOUT MASK"
font = cv2.FONT_HERSHEY_SIMPLEX
scale = 0.8

# %%
def predict(image):
    
    face_frame = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    face_frame = cv2.resize(face_frame, (224, 224))
    face_frame = img_to_array(face_frame)
    face_frame = np.expand_dims(face_frame, axis=0)
    face_frame =  preprocess_input(face_frame)
    prediction = model.predict(face_frame)
    
    return prediction[0][0]

# %%
def detector(gray_image, frame):
    
    faces = face_classifier.detectMultiScale(gray_image, 1.1, 5)
    
    for (x,y,w,h) in faces:

        roi_color = frame[y:y+h, x:x+w]
        mask = predict(roi_color)

        
        if mask > 0.5:
            cv2.rectangle(frame, (x, y), (x+w, y+h), (0,255,0), 2)
            cv2.putText(frame, text =text_mask, org =(x+50,y-100), fontFace =font, fontScale = scale, color =(0,255,0),
            thickness = 3)
            
            
        
        elif mask<=0.5:
            cv2.rectangle(frame, (x, y), (x+w, y+h), (0,0,255), 2)
            cv2.putText(frame, text =text_no_mask, org =(x+50,y-100), fontFace =font, fontScale = scale , color =(0,0,255),
            thickness = 3)
            sound.play()
            
            

            
    return frame

# %%
video_cap = cv2.VideoCapture(0)

while True:
    
    ret, frame = video_cap.read()
    gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    
    detect = detector(gray_frame, frame)
    
    cv2.imshow("Video", detect)
    
    if cv2.waitKey(1) & 0xFF == ord("q"):
        break
        
video_cap.release()
cv2.destroyAllWindows()
# Out:
# ...
# 1/1 [==============================] - 0s 141ms/step
# ...
#    1998         'TPUStrategy and AutoShardPolicy.FILE might lead to out-of-order '
#    1999         'result. Consider setting it to AutoShardPolicy.DATA.',
#    2000         stacklevel=2)
# -> 2002 data_handler = data_adapter.get_data_handler(
#    2003     x=x,
#    2004     batch_size=batch_size,
#    2005     steps_per_epoch=steps,
#    2006     initial_epoch=0,
#    2007     epochs=1,
#    2008     max_queue_size=max_queue_size,
#    2009     workers=workers,
#    2010     use_multiprocessing=use_multiprocessing,
#    2011     model=self,
#    2012     steps_per_execution=self._steps_per_execution)
#    2014 # Container that configures and calls `tf.keras.Callback`s.
#    2015 if not isinstance(callbacks, callbacks_module.CallbackList):
#
# File D:\anaconda\lib\site-packages\keras\engine\data_adapter.py:1401, in get_data_handler(*args, **kwargs)
#    1399 if getattr(kwargs["model"], "_cluster_coordinator", None):
# ...
